# %%
import pandas as pd
import numpy as np
import seaborn as sns
data = pd.read_excel('./Data/car_data_selection.xlsx')
df = pd.DataFrame(data)


categ_variables = df[["categoryHP","aspiration","carbody","cylindernumber","price"]]


current_variable_x = 'carbody'
current_variable_y = 'price'



sns.catplot(x=current_variable_x, y=current_variable_y, data=categ_variables, kind='box', palette="ch:.25")

# for i in categ_variables:
#      print(categ_variables[i].value_counts(normalize=True))
